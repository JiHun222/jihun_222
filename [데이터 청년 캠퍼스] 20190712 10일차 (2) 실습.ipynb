# %%
# !pip install bs4

# %%
from bs4 import BeautifulSoup

# %%
import urllib
import json
import requests

# %%
def download(method,url,param=None,data=None,timeout=1,maxretries=3):#원래 header도 있어야된다. 위에 정의한거 쓸꺼야
  
    try:
        resp=requests.request(method,url,params=param,data=data,headers=headers)
        
        resp.raise_for_status()#강제로 에러를 내는 코드
    except requests.exceptions.HTTPError as e:
        if 500<= e.response.status_code<600 and maxretries>0:
            time.sleep(timeout)
            print("재시도")
            resp=download(method,url,param,data,timeout,maxretries-1)
        else:
            print(e.response.status_code)
            print(e.response.reason)
    return resp
headers = None

# %%
html = download("get", "https://search.naver.com/search.naver?where=image&sm=tab_jum&query=%EC%8A%AC%EA%B8%B0")

# %%
html = html.text

# %%
dom = BeautifulSoup(html,'lxml')

# %%
html
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="슬기 : 네이버 이미지검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'슬기\'의 네이버 이미지검색 결과입니다."> <meta name="description" lang="ko" content="\'슬기\'의 네이버 이미지검색 결과입니다."> <title>슬기 : 네이버 이미지검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_140327.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_190711.css"> <link rel="stylesheet" type="text/css" href=
# ...

# %%
dom.find_all()
# Out:
# [<html lang="ko"> <head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="width=device-width,initial-scale=1.0,maximum-scale=2.0" name="viewport"/> <meta content="슬기 : 네이버 이미지검색" property="og:title"/> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'슬기'의 네이버 이미지검색 결과입니다." property="og:description"/> <meta content="'슬기'의 네이버 이미지검색 결과입니다." lang="ko" name="description"/> <title>슬기 : 네이버 이미지검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_140327.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"/><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_190711.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/
# ...

# %%
dom.find("div", {"class" : "img_area _item"})
# Out:
# <div class="img_area _item" data-id="blog77963|46|221378760163_1083298102"> <a class="thumb _thumb" href="#" onclick="tCR('a=img_noc*b.img&amp;r=1&amp;i=blog_bf6e2ecae0eb26b4be2950431e91ab09&amp;g=458690396799432&amp;u=https%3A%2F%2Fblog.naver.com%2Fleben98%2F221378760163');" title="슬기 | 블로그"> <img alt="슬기 | 블로그" class="_img" data-height="1110" data-source="https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAxODEwMTZfMTc1%2FMDAxNTM5Njc0ODkwNDU3.KDj36d3NjTpnyndIEoiX3j1nf9udHH5so1an1MaSEcAg.dyqv21hIRCKtTrcNpw_BLHBVtsC5-J0qIa6hiDACM_8g.JPEG.leben98%2F%25BD%25BD%25B1%25E2-%25C7%25CE%25C5%25A9%25C7%25C3%25B7%25B9%25C0%25CC01.jpg&amp;type=b400" data-width="740" onerror="var we=$Element(this); we.addClass('bg_nimg'); we.attr('alt','이미지준비중'); we.attr('src','...');" src="..."/><span class="img_border"></span> <span class="data_img"> <span class="data_bg"></span> <span class="data_txt"> <em class="tit">슬기</em> <span class="size">740X1110</span> </span> </span> <span cl
# ...

# %%
overcome = dom.find("div", {"class" : "img_area _item"})

# %%
import re

# %%
re.findall('<img src="(.+?)">',html.text)
# Out:
# ['https://ssl.pstatic.net/sstatic/search/nlogo/20190711171635.png" width="330" height="105" usemap="#link_logo" alt="네이버',
#  'https://ssl.pstatic.net/sstatic/keypage/lifesrch/sports/img2010/bt_ly_close.gif" width="11" height="11" alt="닫기',
#  '..." class="_img" alt="슬기 | 블로그" onerror="var we=$Element(this); we.addClass(\'bg_nimg\'); we.attr(\'alt\',\'이미지준비중\'); we.attr(\'src\',\'...\');" data-source="https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAxODEwMTZfMTc1%2FMDAxNTM5Njc0ODkwNDU3.KDj36d3NjTpnyndIEoiX3j1nf9udHH5so1an1MaSEcAg.dyqv21hIRCKtTrcNpw_BLHBVtsC5-J0qIa6hiDACM_8g.JPEG.leben98%2F%25BD%25BD%25B1%25E2-%25C7%25CE%25C5%25A9%25C7%25C3%25B7%25B9%25C0%25CC01.jpg&type=b400" data-width="740" data-height="1110',
# ...

# %%
haha = re.findall('<img src="(.+?)">',html.text)

# %%
requests.compat.urlparse(haha.url)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-7e7281564390> in <module>
# ----> 1 requests.compat.urlparse(haha.url)
#
# AttributeError: 'list' object has no attribute 'url'

# %%
[requests.compat.urljoin(html.url, _.find_all("td")[-1].find()["src"]) 
 for _ in overcome.children]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-c95d98578f35> in <module>
#       1 [requests.compat.urljoin(html.url, _.find_all("td")[-1].find()["src"])
# ----> 2  for _ in overcome.children]
#
# <ipython-input-58-c95d98578f35> in <listcomp>(.0)
#       1 [requests.compat.urljoin(html.url, _.find_all("td")[-1].find()["src"])
# ----> 2  for _ in overcome.children]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, attr)
#     740             raise AttributeError(
#     741                 "'%s' object has no attribute '%s'" % (
# --> 742                     self.__class__.__name__, attr))
#     743
#     744     def output_ready(self, formatter="minimal"):
#
# AttributeError: 'NavigableString' object has no attribute 'find_all'
