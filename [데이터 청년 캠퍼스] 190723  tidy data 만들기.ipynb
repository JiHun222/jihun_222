# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %% [markdown]
# - category 데이터
# - 일반적인 문자 데이터는 object 데이터
# - category로 지정하면 편리하다(숫자도 문자열도 가능)

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# - 기본적으로 숫자 데이터만 지정

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips.boxplot()

# %%
tips[['total_bill', 'tip']].boxplot()

# %%
tips.groupby('sex').mean() # group by는 묶는 것
# Out:
#         total_bill       tip      size
# sex
# Male     20.744076  3.089618  2.630573
# Female   18.056897  2.833448  2.459770

# %%
tips.groupby('sex').max()
# Out:
#         total_bill   tip  size
# sex
# Male         50.81  10.0     6
# Female       44.30   6.5     6

# %%
tips.groupby('day').mean()
# Out:
#       total_bill       tip      size
# day
# Thur   17.682742  2.771452  2.451613
# Fri    17.151579  2.734737  2.105263
# Sat    20.441379  2.993103  2.517241
# Sun    21.410000  3.255132  2.842105

# %%
tips.groupby(['sex','day']).mean()
# Out:
#              total_bill       tip      size
# sex    day
# Male   Thur   18.714667  2.980333  2.433333
#        Fri    19.857000  2.693000  2.100000
#        Sat    20.802542  3.083898  2.644068
#        Sun    21.887241  3.220345  2.810345
# Female Thur   16.715312  2.575625  2.468750
#        Fri    14.145556  2.781111  2.111111
#        Sat    19.680357  2.801786  2.250000
#        Sun    19.872222  3.367222  2.944444

# %%
tips.groupby(['sex','day', 'time'])['total_bill','tip'].mean()
# Out:
#                     total_bill       tip
# sex    day  time
# Male   Thur Lunch    18.714667  2.980333
#             Dinner         NaN       NaN
#        Fri  Lunch    11.386667  1.900000
#             Dinner   23.487143  3.032857
#        Sat  Lunch          NaN       NaN
#             Dinner   20.802542  3.083898
#        Sun  Lunch          NaN       NaN
#             Dinner   21.887241  3.220345
# Female Thur Lunch    16.648710  2.561935
#             Dinner   18.780000  3.000000
#        Fri  Lunch    13.940000  2.745000
#             Dinner   14.310000  2.810000
#        Sat  Lunch          NaN       NaN
#             Dinner   19.680357  2.801786
#        Sun  Lunch          NaN       NaN
#             Dinner   19.872222  3.367222

# %%
tips.groupby(['sex'])['total_bill','tip'].mean()
# Out:
#         total_bill       tip
# sex
# Male     20.744076  3.089618
# Female   18.056897  2.833448

# %%
t = tips.groupby(['sex'])['total_bill','tip'].mean()

# %%
t.plot.bar()

# %%
t.plot.line()

# %%
t.plot.barh()

# %%
import pandas as pd

# %%
da = pd.read_csv('da.csv', engine = 'python', encoding='cp949')

# %%
da
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 10 columns):
# 연번       81 non-null int64
# 경로당명칭    81 non-null object
# 소재지      81 non-null object
# 부지(㎡)    81 non-null float64
# 건물(㎡)    81 non-null float64
# 회원총계     81 non-null int64
# 남자회원     81 non-null int64
# 여자회원     81 non-null int64
# 전화번호     81 non-null object
# 기준일자     81 non-null object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 6.4+ KB

# %%
da.describe()
# Out:
#               연번        부지(㎡)       건물(㎡)       회원총계       남자회원       여자회원
# count  81.000000    81.000000   81.000000  81.000000  81.000000  81.000000
# mean   41.000000   169.695556  128.246543  36.234568   8.753086  27.518519
# std    23.526581   157.520518   66.870121  12.110194   8.272743  11.860766
# min     1.000000    18.540000   18.540000  17.000000   0.000000   0.000000
# 25%    21.000000    93.000000   79.000000  27.000000   2.000000  20.000000
# 50%    41.000000   154.110000  126.650000  35.000000   6.000000  26.000000
# 75%    61.000000   201.000000  164.200000  41.000000  13.000000  33.000000
# max    81.000000  1293.300000  374.400000  70.000000  35.000000  67.000000

# %% [markdown]
# ### 인덱스 정하기

# %% [markdown]
# 1. 미리 정하기

# %%
da1 = pd.read_csv('da.csv', engine = 'python', encoding='cp949',index_col='연번') #인덱스 정하기

# %%
da1
# Out:
#           경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 연번
# 1         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 2    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 3       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 4        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 5       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 6         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 7       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 8         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 9         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
da
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %% [markdown]
# 2. 실행 후에 하기

# %%
da.set_index('연번')
# Out:
#           경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 연번
# 1         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 2    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 3       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 4        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 5       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 6         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 7       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 8         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 9         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
da
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
# 적용시키려면 재할당해야

# %% [markdown]
# ### 원본 저장

# %%
da_raw = da.copy()

# %%
da.set_index('연번', inplace = True) # 재할당 안해도 들어간다

# %%
da
# Out:
#           경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 연번
# 1         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 2    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 3       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 4        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 5       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 6         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 7       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 8         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 9         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81 entries, 1 to 81
# Data columns (total 9 columns):
# 경로당명칭    81 non-null object
# 소재지      81 non-null object
# 부지(㎡)    81 non-null float64
# 건물(㎡)    81 non-null float64
# 회원총계     81 non-null int64
# 남자회원     81 non-null int64
# 여자회원     81 non-null int64
# 전화번호     81 non-null object
# 기준일자     81 non-null object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 6.3+ KB

# %% [markdown]
# - rangeindex에서 int64 index로 바뀜

# %%
da = pd.read_csv('da.csv', engine = 'python', encoding='cp949')

# %%
da.reset_index() # 지우는 것 ㄴㄴ 새로 만드는 것
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
da.reset_index(drop = True)
# Out:
#           경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 1    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 2       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 3        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 4       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 5         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 6       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 7         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 8         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 9         삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 10      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
da_raw
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
# 새로 가져왔다
da.drop(columns='연번')
# Out:
#           경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 1    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 2       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 3        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 4       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 5         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 6       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 7         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 8         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 9         삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 10      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
da.drop(columns='연번', inplace=True)

# %%
da
# Out:
#           경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 1    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 2       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 3        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 4       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 5         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 6       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 7         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 8         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 9         삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 10      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
da.drop(labels = [2, 3, 4])
# Out:
#           경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 1    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 5         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 6       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 7         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 8         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 9         삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 10      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# 11      광장타운경로당              대구광역시 서구 달구벌대로 1707    76.00   76.00    38     4
# 12        명우경로당           대구광역시 서구 평리로 214 광명아파트    49.60   49.60    24     5
# 13     삼익뉴타운경로당        대구광역시 서구 평리로 236 삼익뉴타운아파트    66.00  132.00    45    13
# ...

# %%
da.drop(labels ='소재지', axis=1)
# Out:
#           경로당명칭    부지(㎡)   건물(㎡)  회원총계  남자회원  여자회원          전화번호        기준일자
# 0         내서경로당   139.80  160.80    40     0    40  053-554-0739  2017-11-10
# 1    시영내당(아)경로당   119.00  119.00    24     6    18  053-567-9772  2017-11-10
# 2       홍실1차경로당    90.00   90.00    41     9    32  053-551-8286  2017-11-10
# 3        황성정경로당   134.74  134.74    40    10    30  053-553-9874  2017-11-10
# 4       홍실2차경로당   154.11  154.11    31     0    31  053-556-8220  2017-11-10
# 5         장수경로당   159.00  112.00    38     5    33  053-572-8123  2017-11-10
# 6       내당2동경로당    93.00   62.64    35    10    25  053-571-1637  2017-11-10
# 7         내당경로당   216.00  183.68    40     5    35  053-565-0437  2017-11-10
# 8         천일경로당   165.00  172.84    17     2    15  053-566-3077  2017-11-10
# 9         삼화경로당   130.00  136.02    30     5    25  053-565-5084  2017-11-10
# 10      삼익맨션경로당   109.09  109.09    25     0    25  053-567-7765  2017-11-10
# ...

# %%
da_row = da.copy()

# %%
da.drop('연번', axis = 1. inplace = True)
# Out:
#   File "<ipython-input-80-f334b349a909>", line 1
#     da.drop('연번', axis = 1. inplace = True)
#                                   ^
# SyntaxError: invalid syntax

# %%
da.rename_axis() @## 딕셔너리 형태로 밖ㅜㄴ다 :
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
da['시'] = '대구광역시'

# %%
da
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 11 columns):
# 연번       81 non-null int64
# 경로당명칭    81 non-null object
# 소재지      81 non-null object
# 부지(㎡)    81 non-null float64
# 건물(㎡)    81 non-null float64
# 회원총계     81 non-null int64
# 남자회원     81 non-null int64
# 여자회원     81 non-null int64
# 전화번호     81 non-null object
# 기준일자     81 non-null object
# 시        81 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 7.0+ KB

# %% [markdown]
# ### 시간 측정 요소

# %% [markdown]
# 1. time 패키지
# 2. calender
# 3. datetime : 가장 많이 사용

# %% [markdown]
# #### 1. time

# %%
import time

# %%
time.time() # 현재 시간
# Out:
# 1563863627.0821936

# %% [markdown]
# #### 3. datetime

# %%
import datetime

# %%
dir(datetime)
# Out:
# ['MAXYEAR',
#  'MINYEAR',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'date',
#  'datetime',
#  'datetime_CAPI',
#  'sys',
#  'time',
#  'timedelta',
#  'timezone',
#  'tzinfo']

# %%
datetime.datetime
# Out:
# datetime.datetime

# %%
from datetime import datetime # 시간 날짜

# %%
a = datetime(2019, 7, 22)

# %%
a.year
# Out:
# 2019

# %%
a.month
# Out:
# 7

# %%
a.day
# Out:
# 22

# %%
from datetime import timedelta

# %%
b = timedelta(3)

# %%
a+ b
# Out:
# datetime.datetime(2019, 7, 25, 0, 0)

# %%
from datetime import date, time

# %%
a = datetime.strptime('2019-07-23', '%Y-%M-%d')

# %%
a
# Out:
# datetime.datetime(2019, 1, 23, 0, 7)

# %%
import numpy as np

# %%
a = np.array([1,2,3])

# %%
a
# Out:
# array([1, 2, 3])

# %%
a.dtype = np.int8

# %%
a
# Out:
# array([1, 0, 0, 0, 2, 0, 0, 0, 3, 0, 0, 0], dtype=int8)

# %%
a.dtype.name = 'int8'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-115-40990b1de7e5> in <module>
# ----> 1 a.dtype.name = 'int8'
#
# AttributeError: attribute 'name' of 'numpy.dtype' objects is not writable

# %%
a.dtype = 'int8'

# %%
a
# Out:
# array([1, 0, 0, 0, 2, 0, 0, 0, 3, 0, 0, 0], dtype=int8)

# %%
a.astype('float64')
# Out:
# array([1., 0., 0., 0., 2., 0., 0., 0., 3., 0., 0., 0.])

# %%
da['기준일자'].dtype
# Out:
# dtype('O')

# %%
# 넘파이 기반
da['기준일자'].shape
# Out:
# (81,)

# %%
da['기준일자'].astype('datetime64')
# Out:
# 0    2017-11-10
# 1    2017-11-10
# 2    2017-11-10
# 3    2017-11-10
# 4    2017-11-10
# 5    2017-11-10
# 6    2017-11-10
# 7    2017-11-10
# 8    2017-11-10
# 9    2017-11-10
# 10   2017-11-10
# 11   2017-11-10
# 12   2017-11-10
# 13   2017-11-10
# 14   2017-11-10
# 15   2017-11-10
# 16   2017-11-10
# 17   2017-11-10
# 18   2017-11-10
# 19   2017-11-10
# 20   2017-11-10
# 21   2017-11-10
# 22   2017-11-10
# 23   2017-11-10
# 24   2017-11-10
# 25   2017-11-10
# 26   2017-11-10
# 27   2017-11-10
# 28   2017-11-10
# 29   2017-11-10
#         ...
# 51   2017-11-10
# 52   2017-11-10
# 53   2017-11-10
# 54   2017-11-10
# 55   2017-11-10
# 56   2017-11-10
# 57   2017-11-10
# 58   2017-11-10
# 59   2017-11-10
# 60   2017-11-10
# 61   2017-11-10
# 62   2017-11-10
# 63   2017-11-10
# 64   2017-11-10
# 65   2017-11-10
# 66   2017-11-10
# 67   2017-11-10
# 68   2017-11-10
# 69   2017-11-10
# 70   2017-11-10
# 71   2017-11-10
# 72   2017-11-10
# 73   2017-11-10
# 74   2017-11-10
# ...

# %%
da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 11 columns):
# 연번       81 non-null int64
# 경로당명칭    81 non-null object
# 소재지      81 non-null object
# 부지(㎡)    81 non-null float64
# 건물(㎡)    81 non-null float64
# 회원총계     81 non-null int64
# 남자회원     81 non-null int64
# 여자회원     81 non-null int64
# 전화번호     81 non-null object
# 기준일자     81 non-null object
# 시        81 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 7.0+ KB

# %%
da['기준일자'].describe()
# Out:
# count             81
# unique             1
# top       2017-11-10
# freq              81
# Name: 기준일자, dtype: object

# %%
pd.to_datetime
# Out:
# <function pandas.core.tools.datetimes.to_datetime(arg, errors='raise', dayfirst=False, yearfirst=False, utc=None, box=True, format=None, exact=True, unit=None, infer_datetime_format=False, origin='unix', cache=False)>

# %%
pd.to_datetime(da['기준일자'])
# Out:
# 0    2017-11-10
# 1    2017-11-10
# 2    2017-11-10
# 3    2017-11-10
# 4    2017-11-10
# 5    2017-11-10
# 6    2017-11-10
# 7    2017-11-10
# 8    2017-11-10
# 9    2017-11-10
# 10   2017-11-10
# 11   2017-11-10
# 12   2017-11-10
# 13   2017-11-10
# 14   2017-11-10
# 15   2017-11-10
# 16   2017-11-10
# 17   2017-11-10
# 18   2017-11-10
# 19   2017-11-10
# 20   2017-11-10
# 21   2017-11-10
# 22   2017-11-10
# 23   2017-11-10
# 24   2017-11-10
# 25   2017-11-10
# 26   2017-11-10
# 27   2017-11-10
# 28   2017-11-10
# 29   2017-11-10
#         ...
# 51   2017-11-10
# 52   2017-11-10
# 53   2017-11-10
# 54   2017-11-10
# 55   2017-11-10
# 56   2017-11-10
# 57   2017-11-10
# 58   2017-11-10
# 59   2017-11-10
# 60   2017-11-10
# 61   2017-11-10
# 62   2017-11-10
# 63   2017-11-10
# 64   2017-11-10
# 65   2017-11-10
# 66   2017-11-10
# 67   2017-11-10
# 68   2017-11-10
# 69   2017-11-10
# 70   2017-11-10
# 71   2017-11-10
# 72   2017-11-10
# 73   2017-11-10
# 74   2017-11-10
# ...

# %%
da
# Out:
#     연번        경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  \
# 0    1        내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40
# 1    2   시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24
# 2    3      홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41
# 3    4       황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40
# 4    5      홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31
# 5    6        장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38
# 6    7      내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35
# 7    8        내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40
# 8    9        천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17
# 9   10        삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30
# 10  11      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25
# ...

# %%
da
# Out:
#           경로당명칭                              소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당         대구광역시 서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 1    시영내당(아)경로당       대구광역시 서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 2       홍실1차경로당     대구광역시 서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 3        황성정경로당                  대구광역시 서구 통학로 46   134.74  134.74    40    10
# 4       홍실2차경로당         대구광역시 서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 5         장수경로당               대구광역시 서구 큰장로9길 9-3   159.00  112.00    38     5
# 6       내당2동경로당            대구광역시 서구 큰장로15길 14-20    93.00   62.64    35    10
# 7         내당경로당              대구광역시 서구 평리로 408-13   216.00  183.68    40     5
# 8         천일경로당          대구광역시 서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 9         삼화경로당           대구광역시 서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 10      삼익맨션경로당                 대구광역시 서구 서대구로 25   109.09  109.09    25     0
# ...

# %%
da['소재지']
# Out:
# 0            대구광역시 서구 달구벌대로361길 35-29
# 1          대구광역시 서구 서대구로8길 15 내당시영아파트
# 2        대구광역시 서구 서대구로8길 49 내당보성홍실아파트
# 3                     대구광역시 서구 통학로 46
# 4            대구광역시 서구 통학로 39 보성2차홍실타운
# 5                  대구광역시 서구 큰장로9길 9-3
# 6               대구광역시 서구 큰장로15길 14-20
# 7                 대구광역시 서구 평리로 408-13
# 8             대구광역시 서구 달구벌대로373길 2-24
# 9              대구광역시 서구 달구벌대로373길 7-5
# 10                   대구광역시 서구 서대구로 25
# 11                대구광역시 서구 달구벌대로 1707
# 12             대구광역시 서구 평리로 214 광명아파트
# 13          대구광역시 서구 평리로 236 삼익뉴타운아파트
# 14                 대구광역시 서구 서대구로3길 43
# 15               대구광역시 서구 당산로51길 28-5
# 16            대구광역시 서구 당산로 260 코오롱아파트
# 17              대구광역시 서구 달구벌대로337길 29
# 18                 대구광역시 서구 서대구로7길 46
# 19                 대구광역시 서구 달서로39길 24
# 20              대구광역시 서구 통학로49길 30-27
# 21                대구광역시 서구 북비산로61길 34
# 22              대구광역시 서구 북비산로61길 43-5
# 23                 대구광역시 서구 통학로52길 30
# 24               대구광역시 서구 북비산로75길 2-3
# ...

# %%
x=da['소재지'].str

# %%
x.replace('대구광역시','')
# Out:
# 0             서구 달구벌대로361길 35-29
# 1           서구 서대구로8길 15 내당시영아파트
# 2         서구 서대구로8길 49 내당보성홍실아파트
# 3                      서구 통학로 46
# 4             서구 통학로 39 보성2차홍실타운
# 5                   서구 큰장로9길 9-3
# 6                서구 큰장로15길 14-20
# 7                  서구 평리로 408-13
# 8              서구 달구벌대로373길 2-24
# 9               서구 달구벌대로373길 7-5
# 10                    서구 서대구로 25
# 11                 서구 달구벌대로 1707
# 12              서구 평리로 214 광명아파트
# 13           서구 평리로 236 삼익뉴타운아파트
# 14                  서구 서대구로3길 43
# 15                서구 당산로51길 28-5
# 16             서구 당산로 260 코오롱아파트
# 17               서구 달구벌대로337길 29
# 18                  서구 서대구로7길 46
# 19                  서구 달서로39길 24
# 20               서구 통학로49길 30-27
# 21                 서구 북비산로61길 34
# 22               서구 북비산로61길 43-5
# 23                  서구 통학로52길 30
# 24                서구 북비산로75길 2-3
# 25           서구 북비산로74길 17 새마을금고
# 26                서구 달성공원로 13-14
# 27                서구 달서로26길 35-8
# ...

# %%
da['소재지'] = x.replace('대구광역시','')

# %%
da
# Out:
#           경로당명칭                         소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당          서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 1    시영내당(아)경로당        서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 2       홍실1차경로당      서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 3        황성정경로당                   서구 통학로 46   134.74  134.74    40    10
# 4       홍실2차경로당          서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 5         장수경로당                서구 큰장로9길 9-3   159.00  112.00    38     5
# 6       내당2동경로당             서구 큰장로15길 14-20    93.00   62.64    35    10
# 7         내당경로당               서구 평리로 408-13   216.00  183.68    40     5
# 8         천일경로당           서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 9         삼화경로당            서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 10      삼익맨션경로당                  서구 서대구로 25   109.09  109.09    25     0
# 11      광장타운경로당               서구 달구벌대로 1707    76.00   76.00    38     4
# ...

# %%
da['구'] = '서구'

# %%
da
# Out:
#           경로당명칭                         소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당          서구 달구벌대로361길 35-29   139.80  160.80    40     0
# 1    시영내당(아)경로당        서구 서대구로8길 15 내당시영아파트   119.00  119.00    24     6
# 2       홍실1차경로당      서구 서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9
# 3        황성정경로당                   서구 통학로 46   134.74  134.74    40    10
# 4       홍실2차경로당          서구 통학로 39 보성2차홍실타운   154.11  154.11    31     0
# 5         장수경로당                서구 큰장로9길 9-3   159.00  112.00    38     5
# 6       내당2동경로당             서구 큰장로15길 14-20    93.00   62.64    35    10
# 7         내당경로당               서구 평리로 408-13   216.00  183.68    40     5
# 8         천일경로당           서구 달구벌대로373길 2-24   165.00  172.84    17     2
# 9         삼화경로당            서구 달구벌대로373길 7-5   130.00  136.02    30     5
# 10      삼익맨션경로당                  서구 서대구로 25   109.09  109.09    25     0
# 11      광장타운경로당               서구 달구벌대로 1707    76.00   76.00    38     4
# ...

# %%
da['소재지'] = da['소재지'].str.replace('서구','')

# %%
da['소재지'] = x.replace('서구','')

# %%
da
# Out:
#           경로당명칭                       소재지    부지(㎡)   건물(㎡)  회원총계  남자회원  여자회원  \
# 0         내서경로당           달구벌대로361길 35-29   139.80  160.80    40     0    40
# 1    시영내당(아)경로당         서대구로8길 15 내당시영아파트   119.00  119.00    24     6    18
# 2       홍실1차경로당       서대구로8길 49 내당보성홍실아파트    90.00   90.00    41     9    32
# 3        황성정경로당                    통학로 46   134.74  134.74    40    10    30
# 4       홍실2차경로당           통학로 39 보성2차홍실타운   154.11  154.11    31     0    31
# 5         장수경로당                 큰장로9길 9-3   159.00  112.00    38     5    33
# 6       내당2동경로당              큰장로15길 14-20    93.00   62.64    35    10    25
# 7         내당경로당                평리로 408-13   216.00  183.68    40     5    35
# 8         천일경로당            달구벌대로373길 2-24   165.00  172.84    17     2    15
# 9         삼화경로당             달구벌대로373길 7-5   130.00  136.02    30     5    25
# 10      삼익맨션경로당                   서대구로 25   109.09  109.09    25     0    25
# ...

# %%
da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 10 columns):
# 경로당명칭    81 non-null object
# 소재지      81 non-null object
# 부지(㎡)    81 non-null float64
# 건물(㎡)    81 non-null float64
# 회원총계     81 non-null int64
# 남자회원     81 non-null int64
# 여자회원     81 non-null int64
# 전화번호     81 non-null object
# 기준일자     81 non-null object
# 구        81 non-null object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 6.4+ KB

# %%
# rename
# astype

# %%
tips['size_'] = tips['size']
tips.drop(columns='size', inplace=True)
tips['size_'] = tips['size_'].astype('category')

# %%
tips = sns.load_dataset('tips')

# %%
tips.sex.value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips.sex.value_counts().iloc[0]
# Out:
# 157

# %%
tips.sex.value_counts().plot.bar()

# %%
tips.sex.unique()
# Out:
# [Female, Male]
# Categories (2, object): [Female, Male]

# %%
tips.sex.nunique()
# Out:
# 2

# %%
t = tips.sex.cat #.cat 하면 추가기능 나온다

# %%
t.name
# Out:
# C:\Users\kgh67\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: `Series.cat.name` has been deprecated. Use `Series.name` instead.
#   """Entry point for launching an IPython kernel.
# 'sex'

# %%
t.codes # 라벨 인코딩
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
# 5      0
# 6      0
# 7      0
# 8      0
# 9      0
# 10     0
# 11     1
# 12     0
# 13     0
# 14     1
# 15     0
# 16     1
# 17     0
# 18     1
# 19     0
# 20     0
# 21     1
# 22     1
# 23     0
# 24     0
# 25     0
# 26     0
# 27     0
# 28     0
# 29     1
#       ..
# 214    1
# 215    1
# 216    0
# 217    0
# 218    0
# 219    1
# 220    0
# 221    1
# 222    0
# 223    1
# 224    0
# 225    1
# 226    1
# 227    0
# 228    0
# 229    1
# 230    0
# 231    0
# 232    0
# 233    0
# 234    0
# 235    0
# 236    0
# 237    0
# 238    1
# 239    0
# 240    1
# 241    0
# 242    0
# 243    1
# Length: 244, dtype: int8

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time size_
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips['size_'] = tips['size_'].astype('category')

# %%
tips['size_'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 6      4
# 1      4
# Name: size_, dtype: int64

# %%
mpg = sns.load_dataset('mpg')

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null float64
# horsepower      392 non-null float64
# weight          398 non-null int64
# acceleration    398 non-null float64
# model_year      398 non-null int64
# origin          398 non-null object
# name            398 non-null object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
# horsepower의 개수가 다르다 . 6개가 missing data

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin             name
# 393          82     usa  ford mustang gl
# 394          82  europe        vw pickup
# 395          82     usa    dodge rampage
# 396          82     usa      ford ranger
# 397          82     usa       chevy s-10

# %%
mpg.sample()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 286  17.6          8         302.0       129.0    3725          13.4
#
#      model_year origin             name
# 286          79    usa  ford ltd landau

# %%
 mpg.head(10).describe()
# Out:
#              mpg  cylinders  displacement  horsepower       weight  \
# count  10.000000       10.0     10.000000   10.000000    10.000000
# mean   15.600000        8.0    374.900000  178.300000  3879.700000
# std     1.577621        0.0     65.722396   35.543557   432.151735
# min    14.000000        8.0    302.000000  130.000000  3433.000000
# 25%    14.250000        8.0    309.750000  150.000000  3462.750000
# 50%    15.000000        8.0    370.000000  177.500000  3771.500000
# 75%    16.750000        8.0    437.250000  210.750000  4333.750000
# max    18.000000        8.0    455.000000  225.000000  4425.000000
#
#        acceleration  model_year
# count     10.000000        10.0
# mean      10.300000        70.0
# std        1.337494         0.0
# min        8.500000        70.0
# 25%        9.250000        70.0
# 50%       10.250000        70.0
# 75%       11.375000        70.0
# max       12.000000        70.0

# %%
import missingno as mino

# %%
dir(mino)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_version',
#  'bar',
#  'dendrogram',
#  'geoplot',
#  'heatmap',
#  'matrix',
#  'missingno',
#  'nullity_filter',
#  'nullity_sort',
#  'utils']

# %%
mino.matrix(mpg)

# %%
mino.dendrogram(mpg)

# %%
mpg[mpg.horsepower.isna()] #masking 기법
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0         NaN    2046          19.0
# 126  21.0          6         200.0         NaN    2875          17.0
# 330  40.9          4          85.0         NaN    1835          17.3
# 336  23.6          4         140.0         NaN    2905          14.3
# 354  34.5          4         100.0         NaN    2320          15.8
# 374  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin                  name
# 32           71     usa            ford pinto
# 126          74     usa         ford maverick
# 330          80  europe  renault lecar deluxe
# 336          80     usa    ford mustang cobra
# 354          81  europe           renault 18i
# 374          82     usa        amc concord dl

# %%
mpg.horsepower.isna().sum() # true 가 1이기 때문
# Out:
# 6

# %%
pd.isna == pd.isnull
# Out:
# True

# %%
mpg[mpg.isna()]
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    NaN        NaN           NaN         NaN     NaN           NaN
# 1    NaN        NaN           NaN         NaN     NaN           NaN
# 2    NaN        NaN           NaN         NaN     NaN           NaN
# 3    NaN        NaN           NaN         NaN     NaN           NaN
# 4    NaN        NaN           NaN         NaN     NaN           NaN
# 5    NaN        NaN           NaN         NaN     NaN           NaN
# 6    NaN        NaN           NaN         NaN     NaN           NaN
# 7    NaN        NaN           NaN         NaN     NaN           NaN
# 8    NaN        NaN           NaN         NaN     NaN           NaN
# 9    NaN        NaN           NaN         NaN     NaN           NaN
# 10   NaN        NaN           NaN         NaN     NaN           NaN
# 11   NaN        NaN           NaN         NaN     NaN           NaN
# 12   NaN        NaN           NaN         NaN     NaN           NaN
# ...

# %%
mpg[mpg.horsepower.isna()]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0         NaN    2046          19.0
# 126  21.0          6         200.0         NaN    2875          17.0
# 330  40.9          4          85.0         NaN    1835          17.3
# 336  23.6          4         140.0         NaN    2905          14.3
# 354  34.5          4         100.0         NaN    2320          15.8
# 374  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin                  name
# 32           71     usa            ford pinto
# 126          74     usa         ford maverick
# 330          80  europe  renault lecar deluxe
# 336          80     usa    ford mustang cobra
# 354          81  europe           renault 18i
# 374          82     usa        amc concord dl

# %%
# na를 없애자

# %%
# 데이터가 너무 안크면 없애면 위험하다
# 가짜 데이터 집어넣자(특정 값)

# %%
mpg.fillna(3)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# 5    15.0          8         429.0       198.0    4341          10.0
# 6    14.0          8         454.0       220.0    4354           9.0
# 7    14.0          8         440.0       215.0    4312           8.5
# 8    14.0          8         455.0       225.0    4425          10.0
# 9    15.0          8         390.0       190.0    3850           8.5
# 10   15.0          8         383.0       170.0    3563          10.0
# 11   14.0          8         340.0       160.0    3609           8.0
# 12   15.0          8         400.0       150.0    3761           9.5
# ...

# %%
mpg.fillna(3).loc[32]
# Out:
# mpg                     25
# cylinders                4
# displacement            98
# horsepower               3
# weight                2046
# acceleration            19
# model_year              71
# origin                 usa
# name            ford pinto
# Name: 32, dtype: object

# %%
from scipy import interpolate

# %%
mpg.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
mpg.describe().T
# Out:
#               count         mean         std     min       25%     50%  \
# mpg           398.0    23.514573    7.815984     9.0    17.500    23.0
# cylinders     398.0     5.454774    1.701004     3.0     4.000     4.0
# displacement  398.0   193.425879  104.269838    68.0   104.250   148.5
# horsepower    392.0   104.469388   38.491160    46.0    75.000    93.5
# weight        398.0  2970.424623  846.841774  1613.0  2223.750  2803.5
# acceleration  398.0    15.568090    2.757689     8.0    13.825    15.5
# model_year    398.0    76.010050    3.697627    70.0    73.000    76.0
#
#                    75%     max
# mpg             29.000    46.6
# cylinders        8.000     8.0
# displacement   262.000   455.0
# horsepower     126.000   230.0
# weight        3608.000  5140.0
# acceleration    17.175    24.8
# model_year      79.000    82.0

# %%
mpg.describe().T.plot.bar()

# %%
mpg.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
mpg.columns[:-2]
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year'],
#       dtype='object')

# %%
mpg[mpg.columns[:-2]]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# 5    15.0          8         429.0       198.0    4341          10.0
# 6    14.0          8         454.0       220.0    4354           9.0
# 7    14.0          8         440.0       215.0    4312           8.5
# 8    14.0          8         455.0       225.0    4425          10.0
# 9    15.0          8         390.0       190.0    3850           8.5
# 10   15.0          8         383.0       170.0    3563          10.0
# 11   14.0          8         340.0       160.0    3609           8.0
# 12   15.0          8         400.0       150.0    3761           9.5
# ...

# %%
mpg[mpg.columns[:-3]]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# 5    15.0          8         429.0       198.0    4341          10.0
# 6    14.0          8         454.0       220.0    4354           9.0
# 7    14.0          8         440.0       215.0    4312           8.5
# 8    14.0          8         455.0       225.0    4425          10.0
# 9    15.0          8         390.0       190.0    3850           8.5
# 10   15.0          8         383.0       170.0    3563          10.0
# 11   14.0          8         340.0       160.0    3609           8.0
# 12   15.0          8         400.0       150.0    3761           9.5
# ...

# %%
mpg[mpg.filter(regex = True)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-227-765a89925022> in <module>
# ----> 1 mpg[mpg.filter(regex = True)]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in filter(self, items, like, regex, axis)
#    4577             def f(x):
#    4578                 return matcher.search(to_str(x)) is not None
# -> 4579             matcher = re.compile(regex)
#    4580             values = labels.map(f)
#    4581             return self.loc(axis=axis)[values]
#
# ~\AppData\Local\Continuum\anaconda3\lib\re.py in compile(pattern, flags)
#     232 def compile(pattern, flags=0):
#     233     "Compile a regular expression pattern, returning a Pattern object."
# --> 234     return _compile(pattern, flags)
#     235
#     236 def purge():
#
# ~\AppData\Local\Continuum\anaconda3\lib\re.py in _compile(pattern, flags)
# ...

# %%
mpg.select_dtypes('object')
# Out:
#      origin                               name
# 0       usa          chevrolet chevelle malibu
# 1       usa                  buick skylark 320
# 2       usa                 plymouth satellite
# 3       usa                      amc rebel sst
# 4       usa                        ford torino
# 5       usa                   ford galaxie 500
# 6       usa                   chevrolet impala
# 7       usa                  plymouth fury iii
# 8       usa                   pontiac catalina
# 9       usa                 amc ambassador dpl
# 10      usa                dodge challenger se
# 11      usa                 plymouth 'cuda 340
# 12      usa              chevrolet monte carlo
# 13      usa            buick estate wagon (sw)
# 14    japan              toyota corona mark ii
# 15      usa                    plymouth duster
# 16      usa                         amc hornet
# 17      usa                      ford maverick
# 18    japan                       datsun pl510
# ...

# %%
mpg.filter(regex = '["weight]').describe().T
# Out:
#               count         mean         std     min       25%     50%  \
# mpg           398.0    23.514573    7.815984     9.0    17.500    23.0
# cylinders     398.0     5.454774    1.701004     3.0     4.000     4.0
# displacement  398.0   193.425879  104.269838    68.0   104.250   148.5
# horsepower    392.0   104.469388   38.491160    46.0    75.000    93.5
# weight        398.0  2970.424623  846.841774  1613.0  2223.750  2803.5
# acceleration  398.0    15.568090    2.757689     8.0    13.825    15.5
# model_year    398.0    76.010050    3.697627    70.0    73.000    76.0
#
#                    75%     max
# mpg             29.000    46.6
# cylinders        8.000     8.0
# displacement   262.000   455.0
# horsepower     126.000   230.0
# weight        3608.000  5140.0
# acceleration    17.175    24.8
# model_year      79.000    82.0

# %%
mpg.filter(regex = '[^weight]').describe()
# Out:
#               mpg   cylinders  displacement  horsepower  acceleration  \
# count  398.000000  398.000000    398.000000  392.000000    398.000000
# mean    23.514573    5.454774    193.425879  104.469388     15.568090
# std      7.815984    1.701004    104.269838   38.491160      2.757689
# min      9.000000    3.000000     68.000000   46.000000      8.000000
# 25%     17.500000    4.000000    104.250000   75.000000     13.825000
# 50%     23.000000    4.000000    148.500000   93.500000     15.500000
# 75%     29.000000    8.000000    262.000000  126.000000     17.175000
# max     46.600000    8.000000    455.000000  230.000000     24.800000
#
#        model_year
# count  398.000000
# mean    76.010050
# std      3.697627
# min     70.000000
# 25%     73.000000
# 50%     76.000000
# 75%     79.000000
# max     82.000000

# %%
mpg.filter(regex = '[^weight]').describe().T.plot.bar(stacked = True);

# %%
import seaborn as sns

# %%
# classification 이면 색 구분 가능하다

# %%
sns.pairplot(mpg)
# regression data면 pairplot 그릴 필요 없다

# %%
mpg.corr() #상관계수
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %%
mpg.cov() #공분산
# Out:
#                       mpg    cylinders  displacement    horsepower  \
# mpg             61.089611   -10.308911   -655.402318   -233.857926
# cylinders      -10.308911     2.893415    168.623214     55.348244
# displacement  -655.402318   168.623214  10872.199152   3614.033744
# horsepower    -233.857926    55.348244   3614.033744   1481.569393
# weight       -5505.211745  1290.695575  82368.423240  28265.620231
# acceleration     9.058930    -2.370842   -156.332976    -73.186967
# model_year      16.741163    -2.193499   -142.717137    -59.036432
#
#                      weight  acceleration  model_year
# mpg            -5505.211745      9.058930   16.741163
# cylinders       1290.695575     -2.370842   -2.193499
# displacement   82368.423240   -156.332976 -142.717137
# horsepower     28265.620231    -73.186967  -59.036432
# weight        717140.990526   -974.899011 -959.946344
# acceleration    -974.899011      7.604848    2.938105
# ...

# %%
mpg.corr()

# %%
# 상관계수는 1에 가까울수록관련성이 크다

# %%
sns.heatmap(mpg.corr(), annot = True)

# %%
sns.heatmap(mpg.corr(), annot = True, cbar = False);

# %%
# 세미콜론은 주석 없애준다

# %%
mpg.filter(regex = '[^weight]').describe().T.boxplot()

# %%
# 아웃라이어를 어떻게 제거할까
# 그렇다고 무조건 제거해도 안된다

# %%
mpg.boxplot()

# %%
mpg.describe([.005,.5,.75])
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 0.5%    10.000000    3.000000     70.000000   47.910000  1753.410000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 0.5%       8.500000   70.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# # melt

# %%
pew = pd.read_csv('pew.txt')

# %%
pew
# Out:
#    religion\t"<$10k"\t"$10-20k"\t"$20-30k"\t"$30-40k"\t"$40-50k"\t"$50-75k"\t"$75-100k"\t"$100-150k"\t">150k"\t"Don't know/refused"
# 0   Agnostic\t27\t34\t60\t81\t76\t137\t122\t109\t8...
# 1     Atheist\t12\t27\t37\t52\t35\t70\t73\t59\t74\t76
# 2    Buddhist\t27\t21\t30\t34\t33\t58\t62\t39\t53\t54
# 3   Catholic\t418\t617\t732\t670\t638\t1116\t949\t...
# 4   Don’t know/refused\t15\t14\t15\t11\t10\t35\t21...
# 5   Evangelical Prot\t575\t869\t1064\t982\t881\t14...
# 6           Hindu\t1\t9\t7\t9\t11\t34\t47\t48\t54\t37
# 7   Historically Black Prot\t228\t244\t236\t238\t1...
# 8   Jehovah's Witness\t20\t27\t24\t24\t21\t30\t15\...
# 9    Jewish\t19\t19\t25\t25\t30\t95\t69\t87\t151\t162
# 10  Mainline Prot\t289\t495\t619\t655\t651\t1107\t...
# 11    Mormon\t29\t40\t48\t51\t56\t112\t85\t49\t42\t69
# 12           Muslim\t6\t7\t9\t10\t9\t23\t16\t8\t6\t22
# 13   Orthodox\t13\t17\t23\t32\t32\t47\t38\t42\t46\t73
# 14  Other Christian\t9\t7\t11\t13\t13\t14\t18\t14\...
# ...

# %% [markdown]
# - tab으로 구분된 파일
# - 해결책
#     - 1. sep
#     - 2. delimiter

# %%
pew = pd.read_csv('pew.txt',  sep = '\t')

# %%
pew # 이런식의 데이터 : wide format
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
# sep = '\t', delimiter = '\t'

# %%
# long format으로 바꾼다 -> 분석용으로 쓰는 데이터
# 첫 번째 인자 : 고정시킬 거. 두번째 인자 : 변수, 값
pew.melt(['religion'])
# Out:
#                     religion            variable  value
# 0                   Agnostic               <$10k     27
# 1                    Atheist               <$10k     12
# 2                   Buddhist               <$10k     27
# 3                   Catholic               <$10k    418
# 4         Don’t know/refused               <$10k     15
# 5           Evangelical Prot               <$10k    575
# 6                      Hindu               <$10k      1
# 7    Historically Black Prot               <$10k    228
# 8          Jehovah's Witness               <$10k     20
# 9                     Jewish               <$10k     19
# 10             Mainline Prot               <$10k    289
# 11                    Mormon               <$10k     29
# 12                    Muslim               <$10k      6
# 13                  Orthodox               <$10k     13
# 14           Other Christian               <$10k      9
# 15              Other Faiths               <$10k     20
# ...

# %%
pew.melt(['religion'], var_name='hello', value_name='hi')
# Out:
#                     religion               hello    hi
# 0                   Agnostic               <$10k    27
# 1                    Atheist               <$10k    12
# 2                   Buddhist               <$10k    27
# 3                   Catholic               <$10k   418
# 4         Don’t know/refused               <$10k    15
# 5           Evangelical Prot               <$10k   575
# 6                      Hindu               <$10k     1
# 7    Historically Black Prot               <$10k   228
# 8          Jehovah's Witness               <$10k    20
# 9                     Jewish               <$10k    19
# 10             Mainline Prot               <$10k   289
# 11                    Mormon               <$10k    29
# 12                    Muslim               <$10k     6
# 13                  Orthodox               <$10k    13
# 14           Other Christian               <$10k     9
# 15              Other Faiths               <$10k    20
# ...

# %%
pew.melt(['religion']).variable.value_counts()
# Out:
# >150k                 18
# Don't know/refused    18
# $75-100k              18
# $20-30k               18
# $10-20k               18
# $100-150k             18
# $40-50k               18
# $50-75k               18
# <$10k                 18
# $30-40k               18
# Name: variable, dtype: int64

# %%
pew = pew.melt(['religion'])

# %%
pew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 3 columns):
# religion    180 non-null object
# variable    180 non-null object
# value       180 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 4.3+ KB

# %%
pew
# Out:
#                     religion            variable  value
# 0                   Agnostic               <$10k     27
# 1                    Atheist               <$10k     12
# 2                   Buddhist               <$10k     27
# 3                   Catholic               <$10k    418
# 4         Don’t know/refused               <$10k     15
# 5           Evangelical Prot               <$10k    575
# 6                      Hindu               <$10k      1
# 7    Historically Black Prot               <$10k    228
# 8          Jehovah's Witness               <$10k     20
# 9                     Jewish               <$10k     19
# 10             Mainline Prot               <$10k    289
# 11                    Mormon               <$10k     29
# 12                    Muslim               <$10k      6
# 13                  Orthodox               <$10k     13
# 14           Other Christian               <$10k      9
# 15              Other Faiths               <$10k     20
# ...

# %%
pew.describe()
# Out:
#              value
# count   180.000000
# mean    197.533333
# std     326.548693
# min       1.000000
# 25%      18.000000
# 50%      46.000000
# 75%     218.500000
# max    1529.000000

# %%
pew.groupby('variable').mean()
# Out:
#                          value
# variable
# $10-20k             154.500000
# $100-150k           177.611111
# $20-30k             186.500000
# $30-40k             183.444444
# $40-50k             171.388889
# $50-75k             288.055556
# $75-100k            221.666667
# <$10k               107.222222
# >150k               144.888889
# Don't know/refused  340.055556

# %%
weather = pd.read_csv('weather.txt',  sep = '\t')

# %%
weather
# Out:
#              id  year  month element     d1     d2     d3     d4     d5  \
# 0   MX000017004  2010      1    TMAX    NaN    NaN    NaN    NaN    NaN
# 1   MX000017004  2010      1    TMIN    NaN    NaN    NaN    NaN    NaN
# 2   MX000017004  2010      2    TMAX    NaN  273.0  241.0    NaN    NaN
# 3   MX000017004  2010      2    TMIN    NaN  144.0  144.0    NaN    NaN
# 4   MX000017004  2010      3    TMAX    NaN    NaN    NaN    NaN  321.0
# 5   MX000017004  2010      3    TMIN    NaN    NaN    NaN    NaN  142.0
# 6   MX000017004  2010      4    TMAX    NaN    NaN    NaN    NaN    NaN
# 7   MX000017004  2010      4    TMIN    NaN    NaN    NaN    NaN    NaN
# 8   MX000017004  2010      5    TMAX    NaN    NaN    NaN    NaN    NaN
# 9   MX000017004  2010      5    TMIN    NaN    NaN    NaN    NaN    NaN
# 10  MX000017004  2010      6    TMAX    NaN    NaN    NaN    NaN    NaN
# 11  MX000017004  2010      6    TMIN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
weather.melt(weather.columns[:4])
# Out:
#               id  year  month element variable  value
# 0    MX000017004  2010      1    TMAX       d1    NaN
# 1    MX000017004  2010      1    TMIN       d1    NaN
# 2    MX000017004  2010      2    TMAX       d1    NaN
# 3    MX000017004  2010      2    TMIN       d1    NaN
# 4    MX000017004  2010      3    TMAX       d1    NaN
# 5    MX000017004  2010      3    TMIN       d1    NaN
# 6    MX000017004  2010      4    TMAX       d1    NaN
# 7    MX000017004  2010      4    TMIN       d1    NaN
# 8    MX000017004  2010      5    TMAX       d1    NaN
# 9    MX000017004  2010      5    TMIN       d1    NaN
# 10   MX000017004  2010      6    TMAX       d1    NaN
# 11   MX000017004  2010      6    TMIN       d1    NaN
# 12   MX000017004  2010      7    TMAX       d1    NaN
# 13   MX000017004  2010      7    TMIN       d1    NaN
# 14   MX000017004  2010      8    TMAX       d1    NaN
# 15   MX000017004  2010      8    TMIN       d1    NaN
# ...

# %%
# na  없애자
weather.melt(weather.columns[:4]).dropna()
# Out:
#               id  year  month element variable  value
# 20   MX000017004  2010     12    TMAX       d1  299.0
# 21   MX000017004  2010     12    TMIN       d1  138.0
# 24   MX000017004  2010      2    TMAX       d2  273.0
# 25   MX000017004  2010      2    TMIN       d2  144.0
# 40   MX000017004  2010     11    TMAX       d2  313.0
# 41   MX000017004  2010     11    TMIN       d2  163.0
# 46   MX000017004  2010      2    TMAX       d3  241.0
# 47   MX000017004  2010      2    TMIN       d3  144.0
# 56   MX000017004  2010      7    TMAX       d3  286.0
# 57   MX000017004  2010      7    TMIN       d3  175.0
# 84   MX000017004  2010     11    TMAX       d4  272.0
# 85   MX000017004  2010     11    TMIN       d4  120.0
# 92   MX000017004  2010      3    TMAX       d5  321.0
# 93   MX000017004  2010      3    TMIN       d5  142.0
# 102  MX000017004  2010      8    TMAX       d5  296.0
# 103  MX000017004  2010      8    TMIN       d5  158.0
# ...

# %%
weather.melt(weather.columns[:4], var_name = 'day').dropna()
# Out:
#               id  year  month element  day  value
# 20   MX000017004  2010     12    TMAX   d1  299.0
# 21   MX000017004  2010     12    TMIN   d1  138.0
# 24   MX000017004  2010      2    TMAX   d2  273.0
# 25   MX000017004  2010      2    TMIN   d2  144.0
# 40   MX000017004  2010     11    TMAX   d2  313.0
# 41   MX000017004  2010     11    TMIN   d2  163.0
# 46   MX000017004  2010      2    TMAX   d3  241.0
# 47   MX000017004  2010      2    TMIN   d3  144.0
# 56   MX000017004  2010      7    TMAX   d3  286.0
# 57   MX000017004  2010      7    TMIN   d3  175.0
# 84   MX000017004  2010     11    TMAX   d4  272.0
# 85   MX000017004  2010     11    TMIN   d4  120.0
# 92   MX000017004  2010      3    TMAX   d5  321.0
# 93   MX000017004  2010      3    TMIN   d5  142.0
# 102  MX000017004  2010      8    TMAX   d5  296.0
# 103  MX000017004  2010      8    TMIN   d5  158.0
# 104  MX000017004  2010     10    TMAX   d5  270.0
# 105  MX000017004  2010     10    TMIN   d5  140.0
# ...

# %%
weather.describe()
# Out:
#          year      month          d1          d2          d3          d4  \
# count    22.0  22.000000    2.000000    4.000000    4.000000    2.000000
# mean   2010.0   6.272727  218.500000  223.250000  211.500000  196.000000
# std       0.0   3.601347  113.844192   82.544432   64.054664  107.480231
# min    2010.0   1.000000  138.000000  144.000000  144.000000  120.000000
# 25%    2010.0   3.250000  178.250000  158.250000  167.250000  158.000000
# 50%    2010.0   6.000000  218.500000  218.000000  208.000000  196.000000
# 75%    2010.0   9.500000  258.750000  283.000000  252.250000  234.000000
# max    2010.0  12.000000  299.000000  313.000000  286.000000  272.000000
#
#                d5          d6          d7          d8  ...  d22        d23  \
# count    8.000000    2.000000    2.000000    2.000000  ...  0.0    4.00000
# mean   208.625000  191.500000  205.000000  231.500000  ...  NaN  205.00000
# std     89.042426  122.329473  107.480231   82.731493  ...  NaN   91.18845
# ...

# %%
weather = weather.melt(weather.columns[:4], var_name = 'day').dropna()

# %%
weather
# Out:
#               id  year  month element  day  value
# 20   MX000017004  2010     12    TMAX   d1  299.0
# 21   MX000017004  2010     12    TMIN   d1  138.0
# 24   MX000017004  2010      2    TMAX   d2  273.0
# 25   MX000017004  2010      2    TMIN   d2  144.0
# 40   MX000017004  2010     11    TMAX   d2  313.0
# 41   MX000017004  2010     11    TMIN   d2  163.0
# 46   MX000017004  2010      2    TMAX   d3  241.0
# 47   MX000017004  2010      2    TMIN   d3  144.0
# 56   MX000017004  2010      7    TMAX   d3  286.0
# 57   MX000017004  2010      7    TMIN   d3  175.0
# 84   MX000017004  2010     11    TMAX   d4  272.0
# 85   MX000017004  2010     11    TMIN   d4  120.0
# 92   MX000017004  2010      3    TMAX   d5  321.0
# 93   MX000017004  2010      3    TMIN   d5  142.0
# 102  MX000017004  2010      8    TMAX   d5  296.0
# 103  MX000017004  2010      8    TMIN   d5  158.0
# 104  MX000017004  2010     10    TMAX   d5  270.0
# 105  MX000017004  2010     10    TMIN   d5  140.0
# ...

# %%
weather.drop(columns=['id','year'], inplace = True)

# %%
weather
# Out:
#      month element  day  value
# 20      12    TMAX   d1  299.0
# 21      12    TMIN   d1  138.0
# 24       2    TMAX   d2  273.0
# 25       2    TMIN   d2  144.0
# 40      11    TMAX   d2  313.0
# 41      11    TMIN   d2  163.0
# 46       2    TMAX   d3  241.0
# 47       2    TMIN   d3  144.0
# 56       7    TMAX   d3  286.0
# 57       7    TMIN   d3  175.0
# 84      11    TMAX   d4  272.0
# 85      11    TMIN   d4  120.0
# 92       3    TMAX   d5  321.0
# 93       3    TMIN   d5  142.0
# 102      8    TMAX   d5  296.0
# 103      8    TMIN   d5  158.0
# 104     10    TMAX   d5  270.0
# 105     10    TMIN   d5  140.0
# 106     11    TMAX   d5  263.0
# 107     11    TMIN   d5   79.0
# 130     12    TMAX   d6  278.0
# 131     12    TMIN   d6  105.0
# 148     10    TMAX   d7  281.0
# 149     10    TMIN   d7  129.0
# 168      8    TMAX   d8  290.0
# 169      8    TMIN   d8  173.0
# 202      3    TMAX  d10  345.0
# 203      3    TMIN  d10  168.0
# 222      2    TMAX  d11  297.0
# ...

# %%
weather.reset_index(drop = True, inplace = True)

# %%
weather
# Out:
#     month element  day  value
# 0      12    TMAX   d1  299.0
# 1      12    TMIN   d1  138.0
# 2       2    TMAX   d2  273.0
# 3       2    TMIN   d2  144.0
# 4      11    TMAX   d2  313.0
# 5      11    TMIN   d2  163.0
# 6       2    TMAX   d3  241.0
# 7       2    TMIN   d3  144.0
# 8       7    TMAX   d3  286.0
# 9       7    TMIN   d3  175.0
# 10     11    TMAX   d4  272.0
# 11     11    TMIN   d4  120.0
# 12      3    TMAX   d5  321.0
# 13      3    TMIN   d5  142.0
# 14      8    TMAX   d5  296.0
# 15      8    TMIN   d5  158.0
# 16     10    TMAX   d5  270.0
# 17     10    TMIN   d5  140.0
# 18     11    TMAX   d5  263.0
# 19     11    TMIN   d5   79.0
# 20     12    TMAX   d6  278.0
# 21     12    TMIN   d6  105.0
# 22     10    TMAX   d7  281.0
# 23     10    TMIN   d7  129.0
# 24      8    TMAX   d8  290.0
# 25      8    TMIN   d8  173.0
# 26      3    TMAX  d10  345.0
# 27      3    TMIN  d10  168.0
# 28      2    TMAX  d11  297.0
# 29      2    TMIN  d11  134.0
# ...

# %%
weather.day = weather.day.str.replace('d', '')

# %%
weather
# Out:
#     month element day  value
# 0      12    TMAX   1  299.0
# 1      12    TMIN   1  138.0
# 2       2    TMAX   2  273.0
# 3       2    TMIN   2  144.0
# 4      11    TMAX   2  313.0
# 5      11    TMIN   2  163.0
# 6       2    TMAX   3  241.0
# 7       2    TMIN   3  144.0
# 8       7    TMAX   3  286.0
# 9       7    TMIN   3  175.0
# 10     11    TMAX   4  272.0
# 11     11    TMIN   4  120.0
# 12      3    TMAX   5  321.0
# 13      3    TMIN   5  142.0
# 14      8    TMAX   5  296.0
# 15      8    TMIN   5  158.0
# 16     10    TMAX   5  270.0
# 17     10    TMIN   5  140.0
# 18     11    TMAX   5  263.0
# 19     11    TMIN   5   79.0
# 20     12    TMAX   6  278.0
# 21     12    TMIN   6  105.0
# 22     10    TMAX   7  281.0
# 23     10    TMIN   7  129.0
# 24      8    TMAX   8  290.0
# 25      8    TMIN   8  173.0
# 26      3    TMAX  10  345.0
# 27      3    TMIN  10  168.0
# 28      2    TMAX  11  297.0
# 29      2    TMIN  11  134.0
# ..    ...     ...  ..    ...
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 4 columns):
# month      66 non-null int64
# element    66 non-null object
# day        66 non-null object
# value      66 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 2.1+ KB

# %%
weather.day = weather.day.astype('int64')

# %%
weather
# Out:
#     month element  day  value
# 0      12    TMAX    1  299.0
# 1      12    TMIN    1  138.0
# 2       2    TMAX    2  273.0
# 3       2    TMIN    2  144.0
# 4      11    TMAX    2  313.0
# 5      11    TMIN    2  163.0
# 6       2    TMAX    3  241.0
# 7       2    TMIN    3  144.0
# 8       7    TMAX    3  286.0
# 9       7    TMIN    3  175.0
# 10     11    TMAX    4  272.0
# 11     11    TMIN    4  120.0
# 12      3    TMAX    5  321.0
# 13      3    TMIN    5  142.0
# 14      8    TMAX    5  296.0
# 15      8    TMIN    5  158.0
# 16     10    TMAX    5  270.0
# 17     10    TMIN    5  140.0
# 18     11    TMAX    5  263.0
# 19     11    TMIN    5   79.0
# 20     12    TMAX    6  278.0
# 21     12    TMIN    6  105.0
# 22     10    TMAX    7  281.0
# 23     10    TMIN    7  129.0
# 24      8    TMAX    8  290.0
# 25      8    TMIN    8  173.0
# 26      3    TMAX   10  345.0
# 27      3    TMIN   10  168.0
# 28      2    TMAX   11  297.0
# 29      2    TMIN   11  134.0
# ...

# %%
weather.sort_values('month', inplace=True)

# %%
weather
# Out:
#     month element  day  value
# 63      1    TMIN   30  145.0
# 62      1    TMAX   30  278.0
# 43      2    TMIN   23  107.0
# 2       2    TMAX    2  273.0
# 3       2    TMIN    2  144.0
# 6       2    TMAX    3  241.0
# 7       2    TMIN    3  144.0
# 29      2    TMIN   11  134.0
# 28      2    TMAX   11  297.0
# 42      2    TMAX   23  299.0
# 27      3    TMIN   10  168.0
# 13      3    TMIN    5  142.0
# 26      3    TMAX   10  345.0
# 38      3    TMAX   16  311.0
# 39      3    TMIN   16  176.0
# 12      3    TMAX    5  321.0
# 50      4    TMAX   27  363.0
# 51      4    TMIN   27  167.0
# 52      5    TMAX   27  332.0
# 53      5    TMIN   27  182.0
# 58      6    TMAX   29  301.0
# 40      6    TMAX   17  280.0
# 41      6    TMIN   17  175.0
# 59      6    TMIN   29  180.0
# 32      7    TMAX   14  299.0
# 9       7    TMIN    3  175.0
# 8       7    TMAX    3  286.0
# 33      7    TMIN   14  165.0
# 45      8    TMIN   23  150.0
# 46      8    TMAX   25  297.0
# ...

# %%
weather.reset_index(drop=True, inplace =True)

# %%
weather
# Out:
#     month element  day  value
# 0       1    TMIN   30  145.0
# 1       1    TMAX   30  278.0
# 2       2    TMIN   23  107.0
# 3       2    TMAX    2  273.0
# 4       2    TMIN    2  144.0
# 5       2    TMAX    3  241.0
# 6       2    TMIN    3  144.0
# 7       2    TMIN   11  134.0
# 8       2    TMAX   11  297.0
# 9       2    TMAX   23  299.0
# 10      3    TMIN   10  168.0
# 11      3    TMIN    5  142.0
# 12      3    TMAX   10  345.0
# 13      3    TMAX   16  311.0
# 14      3    TMIN   16  176.0
# 15      3    TMAX    5  321.0
# 16      4    TMAX   27  363.0
# 17      4    TMIN   27  167.0
# 18      5    TMAX   27  332.0
# 19      5    TMIN   27  182.0
# 20      6    TMAX   29  301.0
# 21      6    TMAX   17  280.0
# 22      6    TMIN   17  175.0
# 23      6    TMIN   29  180.0
# 24      7    TMAX   14  299.0
# 25      7    TMIN    3  175.0
# 26      7    TMAX    3  286.0
# 27      7    TMIN   14  165.0
# 28      8    TMIN   23  150.0
# 29      8    TMAX   25  297.0
# ...

# %%
billboard = pd.read_csv('billboard.csv')

# %%
billboard
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98�
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %%
wed = pd.read_csv('weather.txt', sep = '\t')

# %%
pd.wide_to_long(wed, 'd', ['id', 'year', 'month', 'element'], '')
# Out:
#                                        d
# id          year month element
# MX000017004 2010 1     TMAX    1     NaN
#                                2     NaN
#                                3     NaN
#                                4     NaN
#                                5     NaN
#                                6     NaN
#                                7     NaN
#                                8     NaN
#                                9     NaN
#                                10    NaN
#                                11    NaN
#                                12    NaN
#                                13    NaN
#                                14    NaN
#                                15    NaN
#                                16    NaN
#                                17    NaN
#                                18    NaN
#                                19    NaN
#                                20    NaN
#                                21    NaN
# ...

# %%
pd.wide_to_long(wed, 'd', ['id', 'year', 'month', 'element'], '').dropna()
# Out:
#                                        d
# id          year month element
# MX000017004 2010 1     TMAX    30  278.0
#                        TMIN    30  145.0
#                  2     TMAX    2   273.0
#                                3   241.0
#                                11  297.0
#                                23  299.0
#                        TMIN    2   144.0
#                                3   144.0
#                                11  134.0
#                                23  107.0
#                  3     TMAX    5   321.0
#                                10  345.0
#                                16  311.0
#                        TMIN    5   142.0
#                                10  168.0
#                                16  176.0
#                  4     TMAX    27  363.0
#                        TMIN    27  167.0
#                  5     TMAX    27  332.0
#                        TMIN    27  182.0
#                  6     TMAX    17  280.0
# ...

# %% [markdown]
# ## melt를 쓰는 2 가지 방식
# - melt
# - wide_to_long

# %%
billboard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 83 columns):
# year               317 non-null int64
# artist.inverted    317 non-null object
# track              317 non-null object
# time               317 non-null object
# genre              317 non-null object
# date.entered       317 non-null object
# date.peaked        317 non-null object
# x1st.week          317 non-null int64
# x2nd.week          312 non-null float64
# x3rd.week          307 non-null float64
# x4th.week          300 non-null float64
# x5th.week          292 non-null float64
# x6th.week          280 non-null float64
# x7th.week          269 non-null float64
# x8th.week          260 non-null float64
# x9th.week          253 non-null float64
# x10th.week         244 non-null float64
# x11th.week         236 non-null float64
# x12th.week         222 non-null float64
# x13th.week         210 non-null float64
# x14th.week         204 non-null float64
# ...

# %%
billboard = pd.read_csv('billboard.csv', parse_dates=True)

# %%
billboard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 83 columns):
# year               317 non-null int64
# artist.inverted    317 non-null object
# track              317 non-null object
# time               317 non-null object
# genre              317 non-null object
# date.entered       317 non-null object
# date.peaked        317 non-null object
# x1st.week          317 non-null int64
# x2nd.week          312 non-null float64
# x3rd.week          307 non-null float64
# x4th.week          300 non-null float64
# x5th.week          292 non-null float64
# x6th.week          280 non-null float64
# x7th.week          269 non-null float64
# x8th.week          260 non-null float64
# x9th.week          253 non-null float64
# x10th.week         244 non-null float64
# x11th.week         236 non-null float64
# x12th.week         222 non-null float64
# x13th.week         210 non-null float64
# x14th.week         204 non-null float64
# ...
